# %% [markdown]
# <h1>Déterminer la composition de l’état final d’un système à l’aide d’un langage de programmation :</h1>
# <h3><u>Objectif :</u> Déterminer la composition de l’état final un système siège d’une transformation chimique totale à l’aide d’un langage de programmation.</h3>
# <br>
# On souhaite déterminer la composition de l’état final de la réaction suivante :

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [markdown]
# Compléter et exécuter le programme suivant :

# %%
nA=float(input("Quelle est le nombre de mole du réactif A ? "))
nB=float(input("Quelle est le nombre de mole du réactif B ? "))
a=int(input("Quel est le coefficient stoechiométrique du réactif A ?"))
b=int(input("Quel est le coefficient stoechiométrique du réactif B ?"))
c=int(input("Quel est le coefficient stoechiométrique du produit C?"))
d=int(input("Quel est le coefficient stoechiométrique du produit D?"))
if (...)<(...):
    print ("le réactif A est limitant")
    xmax = ...
elif (...)==(...):
    print ("les réactifs sont dans les proportions stoechiométriques")
    xmax = ...
else:
    print ("le réactif B est limitant")
    xmax = ...
NAf = ...
NBf = ...
NCf = ...
NDf = ...
print  ("nA(final)=",NAf,"mol")
print ("nB(final)=",NBf,"mol")
print ("nC(final)=",NCf,"mol")
print ("nD(final)=",NDf,"mol")

# %% [markdown]
# Utiliser le programme pour déterminer la composition de l’état final de la réaction suivante pour trois valeurs de quantité de matière d’aluminium :
# n(Al) = 0,50 mol, n(Al) = 0,60 mol et n(Al) = 0,90 mol
# <br>
# Les résultats obtenus correspondent-ils aux valeurs attendues ?

# %% [markdown]
# ![image1.jpg](attachment:image1.jpg)

# %% [markdown]
# <h3>Pour aller un peu plus loin en programmation :
# On souhaite tracer des graphiques de quantité de matières en fonction de l'avancement.</h3>

# %% [markdown]
# On étudie la combustion complète du butane dans le dioxygène :

# %%
import matplotlib.pyplot as plt

# Déclaration des coefficients stochiométriques

cs_C4H10 = 2

cs_O2 = 13

cs_CO2 = 8

cs_H2O = 10

# Initialisation des quantités de matières initiales (en mol)

no_C4H10 = float(input("Que vaut la quantité de matière initiale de butane ? : "))

no_O2 = float(input("Que vaut la quantité de matière initiale de dioxygène ? : "))

no_CO2 = 0

no_H2O = 0

# Calcul de l'avancement maximum

x_max_C4H10 = no_C4H10 / cs_C4H10

x_max_O2 = no_O2 / cs_O2

x_max = min(x_max_O2,x_max_C4H10)

# Création des listes

x = [ 0, x_max ]

n_C4H10 = [ (no_C4H10-cs_C4H10*valeur) for valeur in x]

n_O2 = [ (no_O2 - cs_O2*valeur) for valeur in x]

n_CO2 = [ (no_CO2 + cs_CO2*valeur) for valeur in x]

n_H2O = [ (no_H2O + cs_H2O*valeur) for valeur in x]

# Création des courbes

plt.plot(x, n_C4H10, label="C4H10", color='orange')

plt.plot(x, n_O2, label="O2", color='red')

plt.plot(x, n_CO2, label="CO2", color='black')

plt.plot(x, n_H2O, label="H2O", color='blue')

# Réglages axes et grille

liste_des_n_max = [ max(n_C4H10), max(n_O2), max(n_CO2), max(n_H2O) ]

n_max = max(liste_des_n_max)

plt.xlabel("Avancement (mol)")

plt.ylabel("Quantite de matière (mol)")

plt.title("Evolution de la réaction de combustion")

plt.legend(loc='upper center')

plt.axis([0,x_max,0,n_max])

plt.grid()

plt.show()
